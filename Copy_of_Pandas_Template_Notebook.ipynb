# %% [markdown]
# <a href="https://colab.research.google.com/github/feven2552/DataAnalytics_using-panda/blob/main/Copy_of_Pandas_Template_Notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 📘 Setup: Import Essential Libraries
import pandas as pd  # Data manipulation
import numpy as np  # Numerical computation
import matplotlib.pyplot as plt  # Visualization
import seaborn as sns  # Advanced visualization

# Display messages
print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %% [markdown]
# # 📝 Pandas Template Notebook
#
# This notebook is a template to start working on any **Pandas Data Analysis** project.
#
# ### **💡 Features:**
# - Import essential libraries
# - Load datasets from CSV or Excel files
# - Clean and manipulate data (filter, sort, subset)
# - Perform grouping, aggregation, and pivoting
# - Create visualizations using **Matplotlib** and **Seaborn**
#
# Use this notebook to practice, explore, and learn **Pandas** step-by-step.

# %%
# 📊 Sample Data for Practice
data = {
    'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eve'],
    'Age': [25, 32, 30, 29, 42],
    'City': ['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami'],
    'Salary': [50000, 60000, 55000, 52000, 80000]
}

# Create DataFrame
df = pd.DataFrame(data)
print("Sample DataFrame Created:")
display(df)
# Out:
# Sample DataFrame Created:
#       Name  Age         City  Salary
# 0    Alice   25     New York   50000
# 1      Bob   32  Los Angeles   60000
# 2  Charlie   30      Chicago   55000
# 3    David   29      Houston   52000
# 4      Eve   42        Miami   80000

# %% [markdown]
# ## 🧑‍💻 Practice Questions
#
# 1️⃣ **Basic Data Exploration**
# - View the first 3 rows of the DataFrame.
# - View the structure and data types of the DataFrame (`.info()`).
# - Get basic statistics for numeric columns (`.describe()`).
#
# 2️⃣ **Data Filtering**
# - Get all employees who are older than 30.
# - Get all employees whose **Salary** is greater than 55,000.
#
# 3️⃣ **Data Manipulation**
# - Add a new column called `Age in 5 years` where each person's age increases by 5.
# - Add a column for `Salary after Tax` where each person's salary is reduced by 20%.
#
# 4️⃣ **Sorting**
# - Sort employees by **Salary** in descending order.
#
# 5️⃣ **Advanced Filtering**
# - Get all employees who are from **Los Angeles** or **New York**.
#
# 6️⃣ **Group By**
# - Calculate the **average salary** for employees from each city.
#
# 7️⃣ **BONUS: Visualization**
# - Create a bar plot of **City vs. Salary** using Seaborn.

# %%
# 📘 Solution for Basic Data Exploration

# View the first 3 rows
print("First 3 rows of the DataFrame:")
display(df.head(3))
# Out:
# First 3 rows of the DataFrame:
#       Name  Age         City  Salary
# 0    Alice   25     New York   50000
# 1      Bob   32  Los Angeles   60000
# 2  Charlie   30      Chicago   55000

# %%
print("DataFrame Info:")
df.info()
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     5 non-null      int64
#  2   City    5 non-null      object
#  3   Salary  5 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 288.0+ bytes

# %%
print("Basic Statistics:")
display(df.describe())
# Out:
# Basic Statistics:
#              Age        Salary
# count   5.000000      5.000000
# mean   31.600000  59400.000000
# std     6.348228  12116.104985
# min    25.000000  50000.000000
# 25%    29.000000  52000.000000
# 50%    30.000000  55000.000000
# 75%    32.000000  60000.000000
# max    42.000000  80000.000000

# %%
# Get employees older than 30
older_than_30 = df[df['Age'] > 30]
print("Employees older than 30:")
display(older_than_30)
# Out:
# Employees older than 30:
#   Name  Age         City  Salary
# 1  Bob   32  Los Angeles   60000
# 4  Eve   42        Miami   80000

# %%
# Get employees whose salary is above 55,000
high_salary = df[df['Salary'] > 55000]
print("Employees with Salary > 55,000:")
display(high_salary)
# Out:
# Employees with Salary > 55,000:
#   Name  Age         City  Salary
# 1  Bob   32  Los Angeles   60000
# 4  Eve   42        Miami   80000
